# %%
# exact same setup as before, except we don't need the mutations, just the tree itself
import msprime as msp
import demes
import demesdraw

Ne = 1e4
q_anc = 2.0
q = [1.0, 1.5]
m = [0.1]
tau = 4.0
demo = msp.Demography()
demo.add_population(initial_size= (Ne) / (q_anc), name = "anc")
demo.add_population(initial_size = (Ne) / (q[0]), name = "P0")
demo.add_population(initial_size = (Ne) / (q[1]), name = "P1")
demo.set_symmetric_migration_rate(populations=("P0", "P1"), rate= m[0] / (2*Ne))
tmp = [f"P{i}" for i in range(2)]
demo.add_population_split(time = tau * 2 * Ne, derived=tmp, ancestral="anc")
g = demo.to_demes()
# demesdraw.tubes(g)
# print(g)
sample_size = 10
samples = {f"P{i}": sample_size for i in range(2)}
anc = msp.sim_ancestry(samples=samples, demography=demo, recombination_rate=1e-8, sequence_length=1e8)
ts = msp.sim_mutations(anc, rate=1e-8)

# %%
import jax.numpy as jnp
import jax
import jax.experimental.sparse as jesp
import scipy.sparse as sp
from jax.experimental import sparse
from jax.experimental.sparse import BCOO
from jax import lax
import scipy
from jax import vmap
import phlash
from phlash.likelihood.arg import log_density


def _matvec(y, Q, Q1, q):
    n = q.shape[0]
    yn = y[:-1].reshape(n, n)
    yd = jnp.diag(yn)
    ret = Q @ yn + yn @ Q
    ret -= Q1 * yn
    ret -= jnp.diag(q * yd)
    return jnp.append(ret.reshape(n ** 2), q.dot(yd))

def matvec(y, Q, Q1, q):
    return _matvec(jnp.array(y), Q, Q1, q)

def P(v, Q, Q1, q, Lambda):
    return v + matvec(v, Q, Q1, q)/Lambda

def expm_mult_unif(v0, Q, Q1, q, t):
    # Lambda = 2*(Q.sum(1).todense().max() + q.max()) 
    # two people can migrate with 4 edges with max migration 0.1, hence first term and 2 * 1 for max coalescent
    # rate of two people on a graph.
    Lambda = 2*(0.1 * 6) + 2
    # don't need jax.scipy because none of the arguments are related to jax
    N = scipy.stats.poisson.isf(1e-5, 30 * Lambda)
    # N = 200
    w = v0
    ret = 0 * v0
    def f(accum, i):
        w, ret = accum
        ret += jax.scipy.stats.poisson.pmf(i, t * Lambda) * w
        w = P(w, Q, Q1, q, Lambda)
        # This needs to return two arguments so we make the second one to be None
        return (w, ret), None

    (w, ret), _ = jax.lax.scan(f, (w, ret), jnp.arange(1+N))

    return ret[-1]

def unit_vector(size, index):
    # Vector of zeros
    tmp = jnp.zeros(size)
    # ith element will be 1
    # JAX arrays are immutable so we cannot do tmp[index] = 1
    tmp = tmp.at[index].set(1)
    return tmp

# Instead using a coalesce rate c like migration_process jupyter notebook we use q
def solve_ode(time_discretization, init_vertices, q, m, BCOO_indices, index, tau):
    # edges is 0 ONLY IF you have a graph with only a SINGLE node
    num_nodes = len(q)
    shape = (num_nodes, num_nodes)
    if len(m) == 0:
        # If the graph has absolutely no edges then the graph has 0 for every edge weight
        # in the way we code Q.
        copy = jesp.BCOO(((jnp.array([], dtype=jnp.float32), jnp.empty((0, len(shape)), dtype=jnp.int32))), shape=shape)
    else:
        copy = jesp.BCOO((m.astype(float), BCOO_indices.astype(jnp.int64)), shape=shape)
        
    Q = copy + copy.transpose()
    Q1 = Q.sum(0).todense()[:, None] + Q.sum(1).todense()[None, :]    
    e_i = unit_vector(num_nodes, init_vertices[0])
    e_j = unit_vector(num_nodes, init_vertices[1])
    tmp = (e_i.reshape(-1, 1)) @ jnp.array([e_j])
    y0 = jnp.append(jnp.ravel(tmp), 0)
    sol = vmap(expm_mult_unif, in_axes = (None, None, None, None, 0))(y0, Q, Q1, q, time_discretization)
    sol = jnp.insert(sol, 0, 0.0)
    probabilities = jnp.diff(sol)
    prob_not_coal = 1 - sol[index]
    return probabilities, sol, prob_not_coal

def from_pmf(t, p):
    """Initialize a size history from a distribution function of coalescent times.

    Args:
        t: time points
        p: p[i] = probability of coalescing in [t[i], t[i + 1])
    """
    sum_initial = 0.0
    c = []
    p = jnp.clip(p, 0, jnp.inf)
    tol = 1e-4
    # difference in times
    dts = jnp.diff(t)
    p_truncated = p[:-1]

    # scan function
    def scan_fn(carry, inputs):
        sum_i = carry
        dt, p_i = inputs
        x = p_i / (1 - sum_i)
        bad = (x >= 1) | (x <= 0) | jnp.isnan(x) | jnp.isinf(x)
        x_safe = jnp.where(bad, 0., x)
        c_safe = jnp.where(bad, tol, -jnp.log1p(-x_safe) / dt)
        c_final = jnp.where(c_safe > tol, c_safe, tol)
        sum_i = sum_i + p_i
        return sum_i, c_final
    
    inputs = (dts, p_truncated)
    sum_final, c = jax.lax.scan(scan_fn, sum_initial, inputs)
    # Append the last coalescent rate (not identifiable from data)
    c = jnp.append(c, c[-1])
    return jnp.array(t), jnp.array(c)

def density(m, q, tau, q_anc, BCOO_indices, init_vertices, tmrca_span): 
    t = jnp.geomspace(1e-4, jnp.max(tmrca_span[:, 0]), 1000)
    # t = jnp.insert(jnp.geomspace(1e-4, 15.0, 1000), 0, 0.0)
    index = jnp.searchsorted(t, tau, side = "right")
    t_aug = jnp.insert(t, index, tau)
    index = index + 1
    probabilities, sol, p_not_coal = solve_ode(t_aug, init_vertices=init_vertices, q=q, m=m, BCOO_indices=BCOO_indices, index=index, tau=tau)
    # print(probabilities)
    t_aug = jnp.insert(t_aug, 0, 0.0) 
    rates = jnp.diff(t_aug) * (t_aug > tau)[1:] * (q_anc)
    # rates = jnp.diff(jnp.maximum(t_aug, tau)) * q_anc
    cum_rates = jnp.cumsum(rates)
    # cum_rates = (t_aug - tau).clip(0)[1:] * q_anc
    after_tau_surv_probs = jnp.exp(-cum_rates) * p_not_coal
    after_tau_epoch_probs = jnp.abs(jnp.diff(after_tau_surv_probs))

    indices = jnp.arange(len(t)+1)
    after_tau_epoch_probs = jnp.append(after_tau_epoch_probs, 0)
    # Define conditions
    conditions = [
        (indices == index-1),  
        (indices >= index)
    ]

    # Define choices corresponding to each condition
    choices = [
        probabilities[index-1]+after_tau_epoch_probs[index-1],
        after_tau_epoch_probs
    ]

    # Default case (when none of the above conditions are met, use 'a')
    result = jnp.select(conditions, choices, default=probabilities)
    final_probabilities = result.at[-1].set(1-jnp.sum(result))
    # print(final_probabilities)
    # vmap_surv_prob = 1 - np.insert(np.cumsum(final_probabilities), 0, 0)[:-1]
    # vmap_surv_prob

    t = jnp.insert(t, 0, 0.0)
    t, c = from_pmf(t, final_probabilities)
    # c = c / (2*Ne)
    # t = t * 2 * Ne

    # c = c / 2 # ASK JT!!!

    import phlash
    from phlash.likelihood.arg import log_density

    eta = phlash.size_history.SizeHistory(t=t, c=c)
    dm = phlash.size_history.DemographicModel(
        eta=eta, theta=None, rho=1e-8 * 1e4 * 4
    )
    # return -(jnp.sum(jnp.log(c_values) + log_p_values))  # Negative for minimization
    
    return log_density(dm, tmrca_span[None])# , vmap_surv_prob, c

# %%
import jax.numpy as jnp
import jax
def sample_tmrca_spanss(ts, subkey=jax.random.PRNGKey(1), num_pop=2):
    samples = jax.random.choice(subkey, ts.num_samples, shape=(2,), replace=False)
    sample1, sample2 = samples[0], samples[1]

    pop1 = ts.node(sample1.item(0)).population - 1
    pop2 = ts.node(sample2.item(0)).population - 1
    sample_config = (pop1, pop2)

    # Precompute all TMRCAs and spans into arrays
    tmrcas = []
    spans = []
    for tree in ts.trees():
        spans.append(tree.interval.right - tree.interval.left)
        tmrcas.append(tree.tmrca(sample1, sample2) / (2*1e4))
    
    # Convert to JAX arrays
    tmrcas = jnp.array(tmrcas)  # Shape: (num_trees,)
    spans = jnp.array(spans)    # Shape: (num_trees,)
    tmrcas_spans = jnp.stack([tmrcas, spans], axis=1)  # Shape: (num_trees, 2)

    # Merge consecutive spans with same TMRCA
    def merge_spans(carry, x):
        current_tmrca, current_span, idx, output = carry
        tmrca, span = x
        
        # Update each component individually
        new_tmrca = jnp.where(tmrca == current_tmrca, current_tmrca, tmrca)
        new_span = jnp.where(tmrca == current_tmrca, current_span + span, span)
        new_idx = jnp.where(tmrca == current_tmrca, idx, idx + 1)
        new_output = jnp.where(
            tmrca == current_tmrca, 
            output, 
            output.at[idx].set(jnp.array([current_tmrca, current_span]))
        )
        
        return (new_tmrca, new_span, new_idx, new_output), None

    init_carry = (tmrcas_spans[0, 0], 0.0, 0, jnp.full((ts.num_trees, 2), jnp.array([1.0, 0.0])))
    final_carry, _ = jax.lax.scan(merge_spans, init_carry, tmrcas_spans)
    final_tmrca, final_span, _, final_output = final_carry
    final_output = final_output.at[-1].set(jnp.array([final_tmrca, final_span]))
    is_ones = jnp.all(final_output == jnp.array([1.0, 0.0]), axis=1)
    reordered_arr = jnp.concatenate([final_output[~is_ones], final_output[is_ones]])

    return reordered_arr, sample_config

# %%
import networkx as nx
import numpy as np
import jax.experimental.sparse as jesp
import scipy.sparse as sp
graph = nx.Graph()
graph.add_edge(0, 1)
tmp = jesp.BCOO.from_scipy_sparse(sp.triu(nx.adjacency_matrix(graph, np.arange(2)).astype(float)))

# %%
import jax
import jax.numpy as jnp
import optax
from functools import partial

def transform_params(params):
    m_unconstrained, q_unconstrained, tau_unconstrained, q_anc_unconstrained = params
    # Sigmoid maps to (0, 1), then scale to (0, 2)
    m = jax.nn.softplus(m_unconstrained)
    q = jax.nn.softplus(q_unconstrained)
    tau = jax.nn.softplus(tau_unconstrained)
    q_anc = jax.nn.softplus(q_anc_unconstrained)
    return (m, q, tau, q_anc)

def inverse_transform_params(params):
    """Convert constrained params back to unconstrained via inverse softplus."""
    m, q, tau, q_anc = params
    m_unconstrained = jnp.log(jnp.exp(m) - 1)  # Inverse softplus
    q_unconstrained = jnp.log(jnp.exp(q) - 1)
    tau_unconstrained = jnp.log(jnp.exp(tau) - 1)
    q_anc_unconstrained = jnp.log(jnp.exp(q_anc) - 1)
    return (m_unconstrained, q_unconstrained, tau_unconstrained, q_anc_unconstrained)

def loss_fn(params, tmp_indices, sample_config, tmrca_span):
    m, q, tau, q_anc = params
    return -density(m, q, tau, q_anc, tmp_indices, sample_config, tmrca_span)

# 2. Initialize parameters
def init_params(m_shape, q_shape):
    # Initialize with reasonable values for your problem
    m = jnp.ones(m_shape) * 0.001  # Example initialization
    q = jnp.ones(q_shape) * 0.5
    tau = 1.0  # Example initial value
    q_anc = 0.5 # Example initial value

    # Convert to unconstrained space for optimization
    m_unconstrained = jnp.log(jnp.exp(m) - 1)  # Inverse softplus
    q_unconstrained = jnp.log(jnp.exp(q) - 1)
    tau_unconstrained = jnp.log(jnp.exp(tau) - 1)
    q_anc_unconstrained = jnp.log(jnp.exp(q_anc) - 1)
    
    return (m_unconstrained, q_unconstrained, tau_unconstrained, q_anc_unconstrained)
    # return (m, q, tau, q_anc)

# 4. Set up the optimization
def optimize(params, optimizer, tmp_indices, ts, num_steps=1000):
    # Initialize optimizer state
    opt_state = optimizer.init(params)
    
    # Initialize random key
    key = jax.random.PRNGKey(0)
    
    # Define the update step (now without ts)
    @jax.jit
    def step(params, opt_state, tmp_indices, sample_config, tmrca_span):
        # Compute loss and gradients
        params = transform_params(params)
        jax.debug.print("params:{}", params, ordered=True)
        loss, grads = jax.value_and_grad(loss_fn)(params, tmp_indices, sample_config, tmrca_span)

        # Update parameters
        updates, opt_state = optimizer.update(grads, opt_state, params)
        params = optax.apply_updates(params, updates)
        
        return params, opt_state, loss, grads
    
    # Training loop
    losses = []
    for step_num in range(num_steps):
        # Generate new samples outside the JIT-compiled step
        key, subkey = jax.random.split(key)
        tmrca_span, sample_config = sample_tmrca_spanss(ts, subkey)
        
        # Perform optimization step
        params, opt_state, loss, grads = step(params, opt_state, tmp_indices, sample_config, tmrca_span)
        print(inverse_transform_params(params))
        # print(loss)
        # print(grads)
        losses.append(loss)
        
        if step_num % 100 == 0:  # Print progress every 100 steps
            print(f"Step {step_num}, Loss: {loss}")
    
    return params, losses

# Example usage
# Initialize parameters
params = init_params(m_shape=jnp.array(m).shape, q_shape=jnp.array(q).shape)  # Adjust shapes as needed

optimizer = optax.chain(optax.clip_by_global_norm(1.0),
                        optax.adam(learning_rate=0.1)
)

with jax.debug_nans(False), jax.disable_jit(False):
    optimized_params_unconstrained, losses = optimize(
        params, optimizer, tmp.indices, ts, num_steps=1000
    )

# Convert back to constrained space for final results
optimized_params = transform_params(optimized_params_unconstrained)

print("\nOptimized parameters:")
print(f"m: {optimized_params[0]}")
print(f"q: {optimized_params[1]}")
print(f"tau: {optimized_params[2]}")
print(f"q_anc: {optimized_params[3]}")
# Out:
# params:(Array([0.001], dtype=float64), Array([0.5, 0.5], dtype=float64), Array(1., dtype=float64), Array(0.5, dtype=float64))
# (Array([-2.24170977], dtype=float64), Array([-0.19587302, -0.19587302], dtype=float64), Array(0.37816477, dtype=float64), Array(-0.19587078, dtype=float64))
# Step 0, Loss: 463768.7141677801
# params:(Array([0.74492176], dtype=float64), Array([1.03748718, 1.03748718], dtype=float64), Array(1.24115397, dtype=float64), Array(1.03748783, dtype=float64))
# (Array([0.20889823], dtype=float64), Array([0.71323129, 0.71369017], dtype=float64), Array(0.79255207, dtype=float64), Array(0.48321442, dtype=float64))
# params:(Array([1.17320002], dtype=float64), Array([1.39638684, 1.39661861], dtype=float64), Array(1.43723147, dtype=float64), Array(1.28682687, dtype=float64))
# (Array([0.86696662], dtype=float64), Array([1.21860492, 1.22507474], dtype=float64), Array(1.09970292, dtype=float64), Array(0.84488416, dtype=float64))
# params:(Array([1.47697599], dtype=float64), Array([1.68314657, 1.68721723], dtype=float64), Array(1.61009244, dtype=float64), Array(1.46503811, dtype=float64))
# (Array([1.26580386], dtype=float64), Array([1.57118037, 1.58824368], dtype=float64), Array(1.35785271, dtype=float64), Array(1.08303638, dtype=float64))
# params:(Array([1.71306649], dtype=float64), Array([1.9187335 , 1.93081739], dtype=float64), Array(1.77288853, dtype=float64), Array(1.60012151, dtype=float64))
# (Array([1.55507766], dtype=float64), Array([1.85728164, 1.86880554], dtype=float64), Array(1.55126518, dtype=float64), Array(1.2560255, dtype=float64))
# params:(Array([1.90738526], dtype=float64), Array([2.12898124, 2.13777543], dtype=float64), Array(1.90470636, dtype=float64), Array(1.70682548, dtype=float64))
# (Array([1.77921612], dtype=float64), Array([2.0779086 , 2.08423334], dtype=float64), Array(1.73919993, dtype=float64), Array(1.38832387, dtype=float64))
# params:(Array([2.07004881], dtype=float64), Array([2.30135893, 2.30642037], dtype=float64), Array(2.04028313, dtype=float64), Array(1.79311293, dtype=float64))
# (Array([1.96473816], dtype=float64), Array([2.27283318, 2.2800339 ], dtype=float64), Array(1.91497361, dtype=float64), Array(1.49318212, dtype=float64))
# params:(Array([2.21189911], dtype=float64), Array([2.46017527, 2.46614948], dtype=float64), Array(2.17324601, dtype=float64), Array(1.86427196, dtype=float64))
# (Array([2.12050177], dtype=float64), Array([2.42992363, 2.43795772], dtype=float64), Array(2.08656898, dtype=float64), Array(1.57844822, dtype=float64))
# params:(Array([2.33556704], dtype=float64), Array([2.59211655, 2.59895185], dtype=float64), Array(2.30829111, dtype=float64), Array(1.92387308, dtype=float64))
# (Array([2.25361668], dtype=float64), Array([2.55840503, 2.56556372], dtype=float64), Array(2.24836833, dtype=float64), Array(1.64886374, dtype=float64))
# params:(Array([2.44426798], dtype=float64), Array([2.70238093, 2.70858267], dtype=float64), Array(2.43993261, dtype=float64), Array(1.97422917, dtype=float64))
# (Array([2.36910781], dtype=float64), Array([2.66356611, 2.66840678], dtype=float64), Array(2.40205854, dtype=float64), Array(1.70784524, dtype=float64))
# params:(Array([2.54064504], dtype=float64), Array([2.79406656, 2.79831625], dtype=float64), Array(2.56847325, dtype=float64), Array(2.0171752, dtype=float64))
# (Array([2.4704116], dtype=float64), Array([2.74895422, 2.75022901], dtype=float64), Array(2.55147537, dtype=float64), Array(1.75799231, dtype=float64))
# params:(Array([2.62664591], dtype=float64), Array([2.86939106, 2.87052129], dtype=float64), Array(2.69638327, dtype=float64), Array(2.05422367, dtype=float64))
# (Array([2.56153322], dtype=float64), Array([2.82526299, 2.82365959], dtype=float64), Array(2.69873432, dtype=float64), Array(1.80124244, dtype=float64))
# params:(Array([2.70509022], dtype=float64), Array([2.93732849, 2.93589519], dtype=float64), Array(2.82499797, dtype=float64), Array(2.08656219, dtype=float64))
# (Array([2.64158863], dtype=float64), Array([2.87767864, 2.87256366], dtype=float64), Array(2.8434481, dtype=float64), Array(1.83925281, dtype=float64))
# params:(Array([2.77480396], dtype=float64), Array([2.98431574, 2.97971932], dtype=float64), Array(2.95360131, dtype=float64), Array(2.11527133, dtype=float64))
# (Array([2.7128425], dtype=float64), Array([2.91623782, 2.90649973], dtype=float64), Array(2.98408853, dtype=float64), Array(1.87232689, dtype=float64))
# params:(Array([2.83744303], dtype=float64), Array([3.01904163, 3.0102591 ], dtype=float64), Array(3.08046285, dtype=float64), Array(2.14046744, dtype=float64))
# (Array([2.77615153], dtype=float64), Array([2.94152458, 2.92630423], dtype=float64), Array(3.12087341, dtype=float64), Array(1.90127806, dtype=float64))
# params:(Array([2.89353932], dtype=float64), Array([3.04188596, 3.02812904], dtype=float64), Array(3.20543258, dtype=float64), Array(2.1626843, dtype=float64))
# (Array([2.8324754], dtype=float64), Array([2.9552278 , 2.93403341], dtype=float64), Array(3.25566082, dtype=float64), Array(1.92718062, dtype=float64))
# params:(Array([2.94377874], dtype=float64), Array([3.05428875, 3.03511255], dtype=float64), Array(3.32994297, dtype=float64), Array(2.18268759, dtype=float64))
# (Array([2.88237245], dtype=float64), Array([2.95823645, 2.93086819], dtype=float64), Array(3.38884931, dtype=float64), Array(1.95070495, dtype=float64))
# params:(Array([2.98853578], dtype=float64), Array([3.05701404, 3.03225206], dtype=float64), Array(3.45416407, dtype=float64), Array(2.20095585, dtype=float64))
# (Array([2.9256733], dtype=float64), Array([2.95184862, 2.91837935], dtype=float64), Array(3.52136532, dtype=float64), Array(1.97299065, dtype=float64))
# params:(Array([3.02755921], dtype=float64), Array([3.05122876, 3.02097414], dtype=float64), Array(3.5788019, dtype=float64), Array(2.21835025, dtype=float64))
# (Array([2.95526262], dtype=float64), Array([2.93589127, 2.89670934], dtype=float64), Array(3.65270653, dtype=float64), Array(1.99453385, dtype=float64))
# params:(Array([3.05432028], dtype=float64), Array([3.03679195, 3.0014379 ], dtype=float64), Array(3.70324921, dtype=float64), Array(2.23524549, dtype=float64))
# (Array([2.95941533], dtype=float64), Array([2.91123711, 2.86702922], dtype=float64), Array(3.77948018, dtype=float64), Array(2.01747157, dtype=float64))
# params:(Array([3.05808209], dtype=float64), Array([3.01453058, 2.97474866], dtype=float64), Array(3.82413717, dtype=float64), Array(2.25332015, dtype=float64))
# (Array([2.9440295], dtype=float64), Array([2.88449423, 2.83576357], dtype=float64), Array(3.8840442, dtype=float64), Array(2.04603854, dtype=float64))
# params:(Array([3.04415196], dtype=float64), Array([2.99044406, 2.94672106], dtype=float64), Array(3.92435562, dtype=float64), Array(2.27595255, dtype=float64))
# (Array([2.91776099], dtype=float64), Array([2.86012906, 2.80832867], dtype=float64), Array(3.95677641, dtype=float64), Array(2.07998786, dtype=float64))
# params:(Array([3.0204161], dtype=float64), Array([2.96855534, 2.9222031 ], dtype=float64), Array(3.99431237, dtype=float64), Array(2.30302217, dtype=float64))
# (Array([2.88445942], dtype=float64), Array([2.83900807, 2.78380145], dtype=float64), Array(4.00190427, dtype=float64), Array(2.11784851, dtype=float64))
# params:(Array([2.99041275], dtype=float64), Array([2.94962531, 2.90034482], dtype=float64), Array(4.03781334, dtype=float64), Array(2.33342777, dtype=float64))
# (Array([2.84357872], dtype=float64), Array([2.81699446, 2.75878388], dtype=float64), Array(4.03701153, dtype=float64), Array(2.15877804, dtype=float64))
# params:(Array([2.95371831], dtype=float64), Array([2.92993979, 2.87811024], dtype=float64), Array(4.07170305, dtype=float64), Array(2.36654986, dtype=float64))
# (Array([2.79731937], dtype=float64), Array([2.79601507, 2.73421976], dtype=float64), Array(4.07264684, dtype=float64), Array(2.20160018, dtype=float64))
# params:(Array([2.91238456], dtype=float64), Array([2.91122212, 2.85633944], dtype=float64), Array(4.10614399, dtype=float64), Array(2.40147673, dtype=float64))
# (Array([2.7480593], dtype=float64), Array([2.76822893, 2.70344921], dtype=float64), Array(4.10593235, dtype=float64), Array(2.24494152, dtype=float64))
# params:(Array([2.86859773], dtype=float64), Array([2.88649732, 2.82915475], dtype=float64), Array(4.13835047, dtype=float64), Array(2.43710406, dtype=float64))
# (Array([2.6967719], dtype=float64), Array([2.73946221, 2.67167693], dtype=float64), Array(4.14232578, dtype=float64), Array(2.28872985, dtype=float64))
# params:(Array([2.82326852], dtype=float64), Array([2.86098063, 2.80118859], dtype=float64), Array(4.17360323, dtype=float64), Array(2.47337399, dtype=float64))
# (Array([2.66134428], dtype=float64), Array([2.70144468, 2.6322785 ], dtype=float64), Array(4.18761568, dtype=float64), Array(2.32887346, dtype=float64))
# params:(Array([2.79211682], dtype=float64), Array([2.82738722, 2.76665977], dtype=float64), Array(4.21752868, dtype=float64), Array(2.50686133, dtype=float64))
# (Array([2.63867086], dtype=float64), Array([2.66156982, 2.59148351], dtype=float64), Array(4.2064912, dtype=float64), Array(2.36791156, dtype=float64))
# params:(Array([2.77225057], dtype=float64), Array([2.79231471, 2.73108688], dtype=float64), Array(4.235853, dtype=float64), Array(2.53963744, dtype=float64))
# (Array([2.62953263], dtype=float64), Array([2.61586282, 2.54598463], dtype=float64), Array(4.22368872, dtype=float64), Array(2.40297361, dtype=float64))
# params:(Array([2.76425959], dtype=float64), Array([2.75232312, 2.69163498], dtype=float64), Array(4.25255704, dtype=float64), Array(2.56924809, dtype=float64))
# (Array([2.61901801], dtype=float64), Array([2.56683751, 2.49811264], dtype=float64), Array(4.23162495, dtype=float64), Array(2.43745233, dtype=float64))
# params:(Array([2.75507639], dtype=float64), Array([2.70968681, 2.65038739], dtype=float64), Array(4.26026831, dtype=float64), Array(2.59852164, dtype=float64))
# (Array([2.60562835], dtype=float64), Array([2.51635957, 2.44954579], dtype=float64), Array(4.24829474, dtype=float64), Array(2.471228, dtype=float64))
# params:(Array([2.74339999], dtype=float64), Array([2.66607709, 2.60882522], dtype=float64), Array(4.27647118, dtype=float64), Array(2.62734427, dtype=float64))
# (Array([2.59749045], dtype=float64), Array([2.47605952, 2.41179071], dtype=float64), Array(4.24188644, dtype=float64), Array(2.50533054, dtype=float64))
# params:(Array([2.73631318], dtype=float64), Array([2.63147887, 2.57671956], dtype=float64), Array(4.27024148, dtype=float64), Array(2.65658894, dtype=float64))
# (Array([2.59818295], dtype=float64), Array([2.4331243 , 2.37139656], dtype=float64), Array(4.24666107, dtype=float64), Array(2.53516818, dtype=float64))
# params:(Array([2.73691594], dtype=float64), Array([2.59483866, 2.54257335], dtype=float64), Array(4.27488294, dtype=float64), Array(2.68229147, dtype=float64))
# (Array([2.6054308], dtype=float64), Array([2.38827443, 2.32914401], dtype=float64), Array(4.25393814, dtype=float64), Array(2.56068177, dtype=float64))
# params:(Array([2.74322787], dtype=float64), Array([2.55681468, 2.50708778], dtype=float64), Array(4.28195822, dtype=float64), Array(2.70435268, dtype=float64))
# (Array([2.61157087], dtype=float64), Array([2.34288251, 2.28662162], dtype=float64), Array(4.26931457, dtype=float64), Array(2.58540003, dtype=float64))
# params:(Array([2.74857967], dtype=float64), Array([2.51859959, 2.47162152], dtype=float64), Array(4.29691295, dtype=float64), Array(2.72579816, dtype=float64))
# (Array([2.6197252], dtype=float64), Array([2.31151324, 2.25968844], dtype=float64), Array(4.26253887, dtype=float64), Array(2.61044521, dtype=float64))
# params:(Array([2.75569365], dtype=float64), Array([2.49235229, 2.44928844], dtype=float64), Array(4.2903223, dtype=float64), Array(2.74759821, dtype=float64))
# (Array([2.63278235], dtype=float64), Array([2.27761115, 2.22974313], dtype=float64), Array(4.25651396, dtype=float64), Array(2.63145881, dtype=float64))
# params:(Array([2.76710027], dtype=float64), Array([2.46413858, 2.42457947], dtype=float64), Array(4.28446296, dtype=float64), Array(2.76594318, dtype=float64))
# (Array([2.64487097], dtype=float64), Array([2.25559671, 2.21353471], dtype=float64), Array(4.23302399, dtype=float64), Array(2.65128192, dtype=float64))
# params:(Array([2.77767751], dtype=float64), Array([2.44590459, 2.41125965], dtype=float64), Array(4.26162787, dtype=float64), Array(2.78329338, dtype=float64))
# (Array([2.65199553], dtype=float64), Array([2.24406715, 2.21540721], dtype=float64), Array(4.22888223, dtype=float64), Array(2.66460479, dtype=float64))
# params:(Array([2.78391877], dtype=float64), Array([2.4363826 , 2.41279647], dtype=float64), Array(4.25760314, dtype=float64), Array(2.79497822, dtype=float64))
# (Array([2.66638856], dtype=float64), Array([2.23169478, 2.21407399], dtype=float64), Array(4.24311198, dtype=float64), Array(2.67718436, dtype=float64))
# params:(Array([2.79654413], dtype=float64), Array([2.4261859, 2.4117022], dtype=float64), Array(4.27143279, dtype=float64), Array(2.80602861, dtype=float64))
# (Array([2.6855852], dtype=float64), Array([2.21868093, 2.21010979], dtype=float64), Array(4.27289341, dtype=float64), Array(2.68885421, dtype=float64))
# params:(Array([2.81341763], dtype=float64), Array([2.41548456, 2.40845004], dtype=float64), Array(4.30039454, dtype=float64), Array(2.81629492, dtype=float64))
# (Array([2.71120876], dtype=float64), Array([2.21023264, 2.20915141], dtype=float64), Array(4.28187124, dtype=float64), Array(2.70190971, dtype=float64))
# params:(Array([2.83600083], dtype=float64), Array([2.40855079, 2.40766415], dtype=float64), Array(4.30912989, dtype=float64), Array(2.82779722, dtype=float64))
# (Array([2.74921738], dtype=float64), Array([2.20055627, 2.20551001], dtype=float64), Array(4.3041471, dtype=float64), Array(2.71354601, dtype=float64))
# params:(Array([2.86962437], dtype=float64), Array([2.40062203, 2.40467936], dtype=float64), Array(4.33081319, dtype=float64), Array(2.83806415, dtype=float64))
# (Array([2.76757564], dtype=float64), Array([2.19222345, 2.20253473], dtype=float64), Array(4.31989855, dtype=float64), Array(2.72767312, dtype=float64))
# params:(Array([2.88591693], dtype=float64), Array([2.3938053 , 2.40224204], dtype=float64), Array(4.34615333, dtype=float64), Array(2.85054757, dtype=float64))
# (Array([2.76856372], dtype=float64), Array([2.18758739, 2.20281068], dtype=float64), Array(4.33654934, dtype=float64), Array(2.74475578, dtype=float64))
# params:(Array([2.88679478], dtype=float64), Array([2.39001722, 2.40246804], dtype=float64), Array(4.36237612, dtype=float64), Array(2.8656699, dtype=float64))
# (Array([2.77054074], dtype=float64), Array([2.17900672, 2.19797634], dtype=float64), Array(4.33983849, dtype=float64), Array(2.76044815, dtype=float64))
# params:(Array([2.88855154], dtype=float64), Array([2.38301453, 2.39851039], dtype=float64), Array(4.36558154, dtype=float64), Array(2.87958744, dtype=float64))
# (Array([2.76236539], dtype=float64), Array([2.17679143, 2.19863327], dtype=float64), Array(4.33118431, dtype=float64), Array(2.77921711, dtype=float64))
# params:(Array([2.88128953], dtype=float64), Array([2.38120843, 2.39904799], dtype=float64), Array(4.35714824, dtype=float64), Array(2.89626582, dtype=float64))
# (Array([2.75426941], dtype=float64), Array([2.17207762, 2.19600016], dtype=float64), Array(4.31096027, dtype=float64), Array(2.79690916, dtype=float64))
# params:(Array([2.87410457], dtype=float64), Array([2.37736778, 2.39689359], dtype=float64), Array(4.33744768, dtype=float64), Array(2.91201895, dtype=float64))
# (Array([2.74141762], dtype=float64), Array([2.17308113, 2.19887597], dtype=float64), Array(4.27901285, dtype=float64), Array(2.81674058, dtype=float64))
# params:(Array([2.86271249], dtype=float64), Array([2.37818512, 2.39924661], dtype=float64), Array(4.30634847, dtype=float64), Array(2.92971302, dtype=float64))
# (Array([2.71948257], dtype=float64), Array([2.1726686 , 2.20022636], dtype=float64), Array(4.2567818, dtype=float64), Array(2.83665034, dtype=float64))
# params:(Array([2.8433075], dtype=float64), Array([2.37784911, 2.40035194], dtype=float64), Array(4.28472342, dtype=float64), Array(2.94751474, dtype=float64))
# (Array([2.71466462], dtype=float64), Array([2.16690237, 2.19557788], dtype=float64), Array(4.24647338, dtype=float64), Array(2.85118945, dtype=float64))
# params:(Array([2.83905186], dtype=float64), Array([2.37315502, 2.39654818], dtype=float64), Array(4.27470048, dtype=float64), Array(2.960538, dtype=float64))
# (Array([2.72089029], dtype=float64), Array([2.16038285, 2.18966991], dtype=float64), Array(4.25355202, dtype=float64), Array(2.86298527, dtype=float64))
# params:(Array([2.84455136], dtype=float64), Array([2.36785379, 2.39171843], dtype=float64), Array(4.28158278, dtype=float64), Array(2.97111843, dtype=float64))
# (Array([2.71918903], dtype=float64), Array([2.15358593, 2.18361126], dtype=float64), Array(4.24993931, dtype=float64), Array(2.87509502, dtype=float64))
# params:(Array([2.84304814], dtype=float64), Array([2.36233388, 2.38677093], dtype=float64), Array(4.2780701, dtype=float64), Array(2.98199375, dtype=float64))
# (Array([2.70716219], dtype=float64), Array([2.15410645, 2.18808545], dtype=float64), Array(4.25477112, dtype=float64), Array(2.88145889, dtype=float64))
# params:(Array([2.83242985], dtype=float64), Array([2.36275636, 2.39042403], dtype=float64), Array(4.2827682, dtype=float64), Array(2.98771428, dtype=float64))
# (Array([2.71051898], dtype=float64), Array([2.14804305, 2.18480693], dtype=float64), Array(4.25821765, dtype=float64), Array(2.88307703, dtype=float64))
# params:(Array([2.83539199], dtype=float64), Array([2.35783763, 2.38774688], dtype=float64), Array(4.28611973, dtype=float64), Array(2.98916942, dtype=float64))
# (Array([2.7121084], dtype=float64), Array([2.14588899, 2.18492905], dtype=float64), Array(4.24597297, dtype=float64), Array(2.88741212, dtype=float64))
# params:(Array([2.83679496], dtype=float64), Array([2.35609159, 2.38784657], dtype=float64), Array(4.27421399, dtype=float64), Array(2.99306899, dtype=float64))
# (Array([2.70664013], dtype=float64), Array([2.13867936, 2.17956912], dtype=float64), Array(4.23890113, dtype=float64), Array(2.89165779, dtype=float64))
# params:(Array([2.83196927], dtype=float64), Array([2.35025276, 2.38347317], dtype=float64), Array(4.26733975, dtype=float64), Array(2.99688978, dtype=float64))
# (Array([2.71241442], dtype=float64), Array([2.1311012 , 2.17305897], dtype=float64), Array(4.24817569, dtype=float64), Array(2.89379092, dtype=float64))
# params:(Array([2.83706512], dtype=float64), Array([2.34412411, 2.37816707], dtype=float64), Array(4.27635544, dtype=float64), Array(2.99881004, dtype=float64))
# (Array([2.72705885], dtype=float64), Array([2.12412007, 2.16650317], dtype=float64), Array(4.27257904, dtype=float64), Array(2.89448796, dtype=float64))
# params:(Array([2.85000434], dtype=float64), Array([2.33848619, 2.37283024], dtype=float64), Array(4.3000887, dtype=float64), Array(2.99943761, dtype=float64))
# (Array([2.72806745], dtype=float64), Array([2.12843695, 2.17327618], dtype=float64), Array(4.30406154, dtype=float64), Array(2.89309702, dtype=float64))
# params:(Array([2.85089631], dtype=float64), Array([2.34197158, 2.37834401], dtype=float64), Array(4.33072988, dtype=float64), Array(2.99818535, dtype=float64))
# (Array([2.7478371], dtype=float64), Array([2.12740199, 2.1737895 ], dtype=float64), Array(4.33171284, dtype=float64), Array(2.88884258, dtype=float64))
# params:(Array([2.86840076], dtype=float64), Array([2.34113571, 2.37876217], dtype=float64), Array(4.35766322, dtype=float64), Array(2.99435612, dtype=float64))
# (Array([2.78053537], dtype=float64), Array([2.12953253, 2.1767645 ], dtype=float64), Array(4.3421108, dtype=float64), Array(2.88621838, dtype=float64))
# params:(Array([2.89743856], dtype=float64), Array([2.3428566 , 2.38118648], dtype=float64), Array(4.36779617, dtype=float64), Array(2.99199501, dtype=float64))
# (Array([2.81598613], dtype=float64), Array([2.12475213, 2.172163  ], dtype=float64), Array(4.3454022, dtype=float64), Array(2.8815734, dtype=float64))
# params:(Array([2.92903919], dtype=float64), Array([2.33899632, 2.37743731], dtype=float64), Array(4.37100424, dtype=float64), Array(2.98781724, dtype=float64))
# (Array([2.83110946], dtype=float64), Array([2.12667089, 2.17428148], dtype=float64), Array(4.35163323, dtype=float64), Array(2.88196805, dtype=float64))
# params:(Array([2.94255677], dtype=float64), Array([2.34054533, 2.37916299], dtype=float64), Array(4.37707825, dtype=float64), Array(2.98817212, dtype=float64))
# (Array([2.82988242], dtype=float64), Array([2.1342602 , 2.18210196], dtype=float64), Array(4.36176133, dtype=float64), Array(2.88680349, dtype=float64))
# params:(Array([2.9414592], dtype=float64), Array([2.34667779, 2.38553928], dtype=float64), Array(4.38695314, dtype=float64), Array(2.99252141, dtype=float64))
# (Array([2.81534013], dtype=float64), Array([2.14643179, 2.19453701], dtype=float64), Array(4.37503314, dtype=float64), Array(2.89552274, dtype=float64))
# params:(Array([2.92846227], dtype=float64), Array([2.35653151, 2.39569689], dtype=float64), Array(4.39989691, dtype=float64), Array(3.00036935, dtype=float64))
# (Array([2.78985753], dtype=float64), Array([2.16302318, 2.21031017], dtype=float64), Array(4.38902859, dtype=float64), Array(2.90757356, dtype=float64))
# params:(Array([2.90573647], dtype=float64), Array([2.36999995, 2.40861437], dtype=float64), Array(4.41355101, dtype=float64), Array(3.01122715, dtype=float64))
# (Array([2.77218426], dtype=float64), Array([2.16798261, 2.21414257], dtype=float64), Array(4.40465121, dtype=float64), Array(2.91489405, dtype=float64))
# params:(Array([2.89001224], dtype=float64), Array([2.37403402, 2.41175848], dtype=float64), Array(4.42879805, dtype=float64), Array(3.01782922, dtype=float64))
# (Array([2.74462214], dtype=float64), Array([2.17753433, 2.22287894], dtype=float64), Array(4.42149271, dtype=float64), Array(2.92551194, dtype=float64))
# params:(Array([2.86555148], dtype=float64), Array([2.38181403, 2.41893389], dtype=float64), Array(4.44524104, dtype=float64), Array(3.02741349, dtype=float64))
# (Array([2.70922006], dtype=float64), Array([2.19038582, 2.23519107], dtype=float64), Array(4.43775215, dtype=float64), Array(2.9393006, dtype=float64))
# params:(Array([2.83424564], dtype=float64), Array([2.39230341, 2.42906512], dtype=float64), Array(4.4611219, dtype=float64), Array(3.03987457, dtype=float64))
# (Array([2.66768873], dtype=float64), Array([2.20732345, 2.25081024], dtype=float64), Array(4.45534661, dtype=float64), Array(2.95551276, dtype=float64))
# params:(Array([2.79768571], dtype=float64), Array([2.40616556, 2.44194924], dtype=float64), Array(4.47831343, dtype=float64), Array(3.05454684, dtype=float64))
# (Array([2.62153071], dtype=float64), Array([2.22785704, 2.27000502], dtype=float64), Array(4.47011436, dtype=float64), Array(2.97283131, dtype=float64))
# params:(Array([2.7572698], dtype=float64), Array([2.42302754, 2.45783084], dtype=float64), Array(4.49274828, dtype=float64), Array(3.0702452, dtype=float64))
# (Array([2.59765571], dtype=float64), Array([2.24168868, 2.28241999], dtype=float64), Array(4.47178806, dtype=float64), Array(2.98578848, dtype=float64))
# params:(Array([2.73645702], dtype=float64), Array([2.43442067, 2.46813076], dtype=float64), Array(4.49438456, dtype=float64), Array(3.08200674, dtype=float64))
# (Array([2.59004884], dtype=float64), Array([2.24495708, 2.28416976], dtype=float64), Array(4.4781116, dtype=float64), Array(2.99247805, dtype=float64))
# params:(Array([2.72983926], dtype=float64), Array([2.43711689, 2.46958418], dtype=float64), Array(4.50056725, dtype=float64), Array(3.0880845, dtype=float64))
# (Array([2.59373841], dtype=float64), Array([2.24892001, 2.28653391], dtype=float64), Array(4.46710112, dtype=float64), Array(2.9987635, dtype=float64))
# params:(Array([2.73304826], dtype=float64), Array([2.44038813, 2.47154862], dtype=float64), Array(4.48980258, dtype=float64), Array(3.0937985, dtype=float64))
# (Array([2.60752982], dtype=float64), Array([2.24626862, 2.28221077], dtype=float64), Array(4.46930159, dtype=float64), Array(3.0007883, dtype=float64))
# params:(Array([2.74505694], dtype=float64), Array([2.43819926, 2.467957  ], dtype=float64), Array(4.49195371, dtype=float64), Array(3.0956399, dtype=float64))
# (Array([2.60868648], dtype=float64), Array([2.25163228, 2.2877978 ], dtype=float64), Array(4.47667317, dtype=float64), Array(3.00043476, dtype=float64))
# params:(Array([2.74606506], dtype=float64), Array([2.44262831, 2.47259914], dtype=float64), Array(4.49916078, dtype=float64), Array(3.09531836, dtype=float64))
# (Array([2.60350141], dtype=float64), Array([2.26253362, 2.2997618 ], dtype=float64), Array(4.47051412, dtype=float64), Array(3.00100286, dtype=float64))
# params:(Array([2.74154704], dtype=float64), Array([2.45164281, 2.48255446], dtype=float64), Array(4.4931391, dtype=float64), Array(3.09583504, dtype=float64))
# (Array([2.58866639], dtype=float64), Array([2.27819163, 2.31722053], dtype=float64), Array(4.46373333, dtype=float64), Array(3.00042967, dtype=float64))
# params:(Array([2.72863727], dtype=float64), Array([2.46462031, 2.49711767], dtype=float64), Array(4.4865105, dtype=float64), Array(3.09531373, dtype=float64))
# (Array([2.59024504], dtype=float64), Array([2.28298238, 2.32312525], dtype=float64), Array(4.45544411, dtype=float64), Array(2.99534864, dtype=float64))
# params:(Array([2.73000987], dtype=float64), Array([2.46859786, 2.50205261], dtype=float64), Array(4.47840871, dtype=float64), Array(3.09069371, dtype=float64))
# (Array([2.60562782], dtype=float64), Array([2.27961682, 2.32030182], dtype=float64), Array(4.45488781, dtype=float64), Array(2.98650728, dtype=float64))
# params:(Array([2.74339953], dtype=float64), Array([2.46580325, 2.4996923 ], dtype=float64), Array(4.47786505, dtype=float64), Array(3.08265962, dtype=float64))
# (Array([2.63532977], dtype=float64), Array([2.27073033, 2.31148154], dtype=float64), Array(4.46031641, dtype=float64), Array(2.97478386, dtype=float64))
# params:(Array([2.76932787], dtype=float64), Array([2.45843198, 2.49232584], dtype=float64), Array(4.48317066, dtype=float64), Array(3.07201668, dtype=float64))
# (Array([2.64887525], dtype=float64), Array([2.27020631, 2.31107923], dtype=float64), Array(4.46588352, dtype=float64), Array(2.96581767, dtype=float64))
# params:(Array([2.78118466], dtype=float64), Array([2.45799766, 2.4919901 ], dtype=float64), Array(4.48861233, dtype=float64), Array(3.06388464, dtype=float64))
# (Array([2.68178607], dtype=float64), Array([2.26698681, 2.30761778], dtype=float64), Array(4.46963051, dtype=float64), Array(2.95575785, dtype=float64))
# params:(Array([2.81007515], dtype=float64), Array([2.45533011, 2.48910231], dtype=float64), Array(4.49227526, dtype=float64), Array(3.05476883, dtype=float64))
# (Array([2.72542148], dtype=float64), Array([2.25974907, 2.29980159], dtype=float64), Array(4.48360422, dtype=float64), Array(2.9444042, dtype=float64))
# params:(Array([2.84855654], dtype=float64), Array([2.44933861, 2.4825876 ], dtype=float64), Array(4.50593823, dtype=float64), Array(3.04449097, dtype=float64))
# (Array([2.75710739], dtype=float64), Array([2.26090911, 2.29970836], dtype=float64), Array(4.48110105, dtype=float64), Array(2.93938508, dtype=float64))
# params:(Array([2.87662246], dtype=float64), Array([2.4502984 , 2.48250995], dtype=float64), Array(4.50349041, dtype=float64), Array(3.03995097, dtype=float64))
# (Array([2.77721106], dtype=float64), Array([2.26005997, 2.29741545], dtype=float64), Array(4.47015713, dtype=float64), Array(2.9364457, dtype=float64))
# params:(Array([2.89448156], dtype=float64), Array([2.44959582, 2.48060048], dtype=float64), Array(4.4927901, dtype=float64), Array(3.03729319, dtype=float64))
# (Array([2.783888], dtype=float64), Array([2.26130578, 2.29706   ], dtype=float64), Array(4.45574007, dtype=float64), Array(2.93729174, dtype=float64))
# params:(Array([2.90042184], dtype=float64), Array([2.45062664, 2.48030453], dtype=float64), Array(4.47869795, dtype=float64), Array(3.03805809, dtype=float64))
# (Array([2.7818487], dtype=float64), Array([2.26839748, 2.30289624], dtype=float64), Array(4.43088956, dtype=float64), Array(2.94264793, dtype=float64))
# params:(Array([2.89860707], dtype=float64), Array([2.45649875, 2.48516595], dtype=float64), Array(4.45441837, dtype=float64), Array(3.04290211, dtype=float64))
# (Array([2.76867756], dtype=float64), Array([2.2793152 , 2.31298684], dtype=float64), Array(4.41169475, dtype=float64), Array(2.95170809, dtype=float64))
# params:(Array([2.88689592], dtype=float64), Array([2.46555287, 2.49358227], dtype=float64), Array(4.43567412, dtype=float64), Array(3.05110153, dtype=float64))
# (Array([2.75217547], dtype=float64), Array([2.28188393, 2.31450381], dtype=float64), Array(4.39504563, dtype=float64), Array(2.95824069, dtype=float64))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 95
#      90 optimizer = optax.chain(optax.clip_by_global_norm(1.0),
#      91                         optax.adam(learning_rate=0.1)
#      92 )
#      94 with jax.debug_nans(False), jax.disable_jit(False):
# ---> 95     optimized_params_unconstrained, losses = optimize(
#      96         params, optimizer, tmp.indices, ts, num_steps=1000
#      97     )
#      99 # Convert back to constrained space for final results
#     100 optimized_params = transform_params(optimized_params_unconstrained)
#
# Cell In[9], line 72, in optimize(params, optimizer, tmp_indices, ts, num_steps)
#      69 for step_num in range(num_steps):
#      70     # Generate new samples outside the JIT-compiled step
#      71     key, subkey = jax.random.split(key)
# ---> 72     tmrca_span, sample_config = sample_tmrca_spanss(ts, subkey)
#      74     # Perform optimization step
#      75     params, opt_state, loss, grads = step(params, opt_state, tmp_indices, sample_config, tmrca_span)
#
# Cell In[7], line 41, in sample_tmrca_spanss(ts, subkey, num_pop)
#      38     return (new_tmrca, new_span, new_idx, new_output), None
#      40 init_carry = (tmrcas_spans[0, 0], 0.0, 0, jnp.full((ts.num_trees, 2), jnp.array([1.0, 0.0])))
# ---> 41 final_carry, _ = jax.lax.scan(merge_spans, init_carry, tmrcas_spans)
#      42 final_tmrca, final_span, _, final_output = final_carry
#      43 final_output = final_output.at[-1].set(jnp.array([final_tmrca, final_span]))
#
#     [... skipping hidden 1 frame]
#
# File ~/opt/Demes/lib/python3.12/site-packages/jax/_src/lax/control_flow/loops.py:331, in scan(f, init, xs, length, reverse, unroll, _split_transpose)
#     329   in_flat = [*in_state, *in_carry, *in_ext]
#     330   num_carry += len(attrs_tracked)
# --> 331 out = scan_p.bind(*consts, *in_flat,
#     332                   reverse=reverse, length=length, jaxpr=jaxpr,
#     333                   num_consts=len(consts), num_carry=num_carry,
#     334                   linear=(False,) * (len(consts) + len(in_flat)),
#     335                   unroll=unroll,
#     336                   _split_transpose=_split_transpose)
#     337 if attrs_tracked:
#     338   out_state, out = split_list(out, [len(attrs_tracked)])
#
# File ~/opt/Demes/lib/python3.12/site-packages/jax/_src/core.py:463, in Primitive.bind(self, *args, **params)
#     461 trace_ctx.set_trace(eval_trace)
#     462 try:
# --> 463   return self.bind_with_trace(prev_trace, args, params)
#     464 finally:
#     465   trace_ctx.set_trace(prev_trace)
#
# File ~/opt/Demes/lib/python3.12/site-packages/jax/_src/core.py:468, in Primitive.bind_with_trace(self, trace, args, params)
#     467 def bind_with_trace(self, trace, args, params):
# --> 468   return trace.process_primitive(self, args, params)
#
# File ~/opt/Demes/lib/python3.12/site-packages/jax/_src/core.py:954, in EvalTrace.process_primitive(self, primitive, args, params)
#     952       return primitive.bind_with_trace(arg._trace, args, params)
#     953 check_eval_args(args)
# --> 954 return primitive.impl(*args, **params)
#
# File ~/opt/Demes/lib/python3.12/site-packages/jax/_src/dispatch.py:89, in apply_primitive(prim, *args, **params)
#      87 prev = lib.jax_jit.swap_thread_local_state_disable_jit(False)
#      88 try:
# ---> 89   outs = fun(*args)
#      90 finally:
#      91   lib.jax_jit.swap_thread_local_state_disable_jit(prev)
#
#     [... skipping hidden 1 frame]
#
# File ~/opt/Demes/lib/python3.12/site-packages/jax/_src/pjit.py:340, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     335 if config.no_tracing.value:
#     336   raise RuntimeError(f"re-tracing function {jit_info.fun_sourceinfo} for "
#     337                      "`jit`, but 'no_tracing' is set")
#     339 (outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked, executable,
# --> 340  pgle_profiler) = _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     342 maybe_fastpath_data = _get_fastpath_data(
#     343     executable, out_tree, args_flat, out_flat, attrs_tracked, jaxpr.effects,
#     344     jaxpr.consts, jit_info.abstracted_axes,
#     345     pgle_profiler)
#     347 return outs, maybe_fastpath_data, _need_to_rebuild_with_fdo(pgle_profiler)
#
# File ~/opt/Demes/lib/python3.12/site-packages/jax/_src/pjit.py:198, in _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     196   args_flat = map(core.full_lower, args_flat)
#     197   core.check_eval_args(args_flat)
# --> 198   out_flat, compiled, profiler = _pjit_call_impl_python(*args_flat, **p.params)
#     199 else:
#     200   out_flat = pjit_p.bind(*args_flat, **p.params)
#
# File ~/opt/Demes/lib/python3.12/site-packages/jax/_src/pjit.py:1692, in _pjit_call_impl_python(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, resource_env, donated_invars, name, keep_unused, inline, compiler_options_kvs, *args)
#    1684   distributed_debug_log(("Running pjit'd function", name),
#    1685                         ("in_shardings", in_shardings),
#    1686                         ("out_shardings", out_shardings),
#    (...)   1689                         ("abstract args", map(core.abstractify, args)),
#    1690                         ("fingerprint", fingerprint))
#    1691 try:
# -> 1692   return compiled.unsafe_call(*args), compiled, pgle_profiler
#    1693 except FloatingPointError as e:
#    1694   assert config.debug_nans.value or config.debug_infs.value  # compiled_fun can only raise in this case
#
# File ~/opt/Demes/lib/python3.12/site-packages/jax/_src/profiler.py:333, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     330 @wraps(func)
#     331 def wrapper(*args, **kwargs):
#     332   with TraceAnnotation(name, **decorator_kwargs):
# --> 333     return func(*args, **kwargs)
#     334   return wrapper
#
# File ~/opt/Demes/lib/python3.12/site-packages/jax/_src/interpreters/pxla.py:1298, in ExecuteReplicated.__call__(self, *args)
#    1296   self._handle_token_bufs(result_token_bufs, sharded_runtime_token)
#    1297 else:
# -> 1298   results = self.xla_executable.execute_sharded(input_bufs)
#    1300 if dispatch.needs_check_special():
#    1301   out_arrays = results.disassemble_into_single_device_arrays()
#
# KeyboardInterrupt:
